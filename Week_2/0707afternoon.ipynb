# %%
birthday = "Happy Birthday Jace!"
ls = list(birthday)
print(ls)

for i in range(0, len(ls), 7):
    ls[i] = "7"

print("".join(ls))
# Out:
# ['H', 'a', 'p', 'p', 'y', ' ', 'B', 'i', 'r', 't', 'h', 'd', 'a', 'y', ' ', 'J', 'a', 'c', 'e', '!']
# 7appy B7rthday7Jace!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

stock = pd.read_csv("RBLX.csv")
stock = stock.drop(0)

opening_prices = stock["Open"].to_numpy()
closing_prices = stock["Close"].to_numpy()
dates = pd.to_datetime(stock["Date"]).to_numpy()

# fig, ax = plt.subplots(figsize=(9, 5))

# line = ax.plot(dates, closing_prices, color='#1f77b4', linestyle='-', linewidth=0.5)
# ax.set_title("Closing Prices of Roblox from 01/01/2021 to 12/31/2025", fontsize=14, fontweight='bold', pad=15)
# ax.set_xlabel("Date", fontsize=11)
# ax.set_ylabel("Closing Price ($)", fontsize=11)
# plt.show()

# weeks = len(stock[stock["Weekday"]=="Monday"])
# yields = np.zeros(5)
# weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
# returns = stock[["Weekday", "Return"]]

# for i in range(0, len(returns)):
#     yields[weekdays.index(returns["Weekday"].iloc[i])] += returns["Return"].iloc[i]

# print(yields)

digits = list("0123456789")
dict = {}
for digit in digits:
    dict[digit] = 0

for i in range(0, len(closing_prices)):
    num = str(closing_prices[i])
    # if (len(num) == 4): dict["0"] += 1
    # else: dict[num[4]] += 1
    dict[num[0]] += 1

for digit in digits:
    dict[digit] = dict[digit]/len(closing_prices) * 100
    print(f"Ending in {digit}: {round(dict[digit], 2)}%")
# Out:
# Ending in 0: 0.0%
# Ending in 1: 11.5%
# Ending in 2: 5.87%
# Ending in 3: 27.54%
# Ending in 4: 22.25%
# Ending in 5: 6.37%
# Ending in 6: 6.78%
# Ending in 7: 7.69%
# Ending in 8: 8.19%
# Ending in 9: 3.8%

# %% [markdown]
# Ending in 0: 11.17%
# Ending in 1: 11.08%
# Ending in 2: 9.76%
# Ending in 3: 8.11%
# Ending in 4: 10.59%
# Ending in 5: 10.09%
# Ending in 6: 10.84%
# Ending in 7: 10.09%
# Ending in 8: 9.76%
# Ending in 9: 8.52%
