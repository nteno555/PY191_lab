# %%
birthday = "Happy Birthday Jace!"
ls = list(birthday)
print(ls)

for i in range(0, len(ls), 7):
    ls[i] = "7"

print("".join(ls))
# Out:
# ['H', 'a', 'p', 'p', 'y', ' ', 'B', 'i', 'r', 't', 'h', 'd', 'a', 'y', ' ', 'J', 'a', 'c', 'e', '!']
# 7appy B7rthday7Jace!
